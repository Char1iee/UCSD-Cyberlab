# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense

import numpy as np
import pandas as pd

from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV
from scikeras.wrappers import KerasClassifier

from warnings import simplefilter
# Out:
# 2024-01-30 00:26:36.821190: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-01-30 00:26:36.825466: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 00:26:37.029488: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-01-30 00:26:37.029546: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-01-30 00:26:37.031554: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-01-30 00:26:37.039787: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-01-30 00:26:37.121316: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI AVX512_BF16 AVX_VNNI AMX_TILE AMX_INT8 AMX_BF16 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-01-30 00:26:42.828625: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
#with two dataset splitted
dftrain = pd.read_csv("/home/jovyan/MQTTset/train70_reduced.csv") 
dftest = pd.read_csv("/home/jovyan/MQTTset/test30_reduced.csv")

# dftrain = pd.read_csv("train70.csv", low_memory=False) 
# dftest = pd.read_csv("test30.csv", low_memory=False)

simplefilter(action='ignore', category=FutureWarning)
seed = 7

# %%
#train
#print(dftrain.loc[dftrain['target'] == 'legitimate'])
class_names = dftrain.target.unique()
dftrain=dftrain.astype('category')
cat_columns = dftrain.select_dtypes(['category']).columns
dftrain[cat_columns] = dftrain[cat_columns].apply(lambda x: x.cat.codes)
#print(dftrain.loc[125, 'target'])
x_columns = dftrain.columns.drop('target')
x_train = dftrain[x_columns].values
y_train = dftrain['target']

#test
class_names = dftest.target.unique()
dftest=dftest.astype('category')
cat_columns = dftest.select_dtypes(['category']).columns
dftest[cat_columns] = dftest[cat_columns].apply(lambda x: x.cat.codes)
x_columns = dftest.columns.drop('target')
x_test = dftest[x_columns].values
y_test = dftest['target']

print("Ready to generate train and test datasets")
# Out:
# Ready to generate train and test datasets

# %%
def calculate_performance_metrics(x_test, y_test, model):

    # Predictions
    y_pred = model.predict(x_test)
    y_pred_classes = np.argmax(y_pred, axis=1)
    
    # Compute metrics
    precision = metrics.precision_score(y_test, y_pred_classes, average='weighted')
    accuracy = metrics.accuracy_score(y_test, y_pred_classes)
    f1 = metrics.f1_score(y_test, y_pred_classes, average='macro')
    auc = metrics.roc_auc_score(y_test, y_pred, multi_class='ovr')

    print(f"Precision: {precision}\nAccuracy: {accuracy}\nF1 Score: {f1}\nAUC: {auc}")
    
    # Confusion matrix for FNR, TNR, FPR, TPR
    cm = metrics.confusion_matrix(y_test, y_pred_classes)
    def calculate_rates(conf_matrix, class_index):
        tp = conf_matrix[class_index, class_index]
        fn = np.sum(conf_matrix[class_index, :]) - tp
        fp = np.sum(conf_matrix[:, class_index]) - tp
        tn = np.sum(conf_matrix) - (tp + fn + fp)
    
        fnr = fn / (fn + tp)
        tnr = tn / (tn + fp)
        fpr = fp / (fp + tn)
        tpr = tp / (tp + fn)
        return fnr, tnr, fpr, tpr

    # Calculate and aggregate rates
    fnrs, tnrs, fprs, tprs = [], [], [], []
    for i in range(cm.shape[0]):
        fnr, tnr, fpr, tpr = calculate_rates(cm, i)
        fnrs.append(fnr)
        tnrs.append(tnr)
        fprs.append(fpr)
        tprs.append(tpr)
    
    mean_fnr = np.mean(fnrs)
    mean_tnr = np.mean(tnrs)
    mean_fpr = np.mean(fprs)
    mean_tpr = np.mean(tprs)

    # Printing the mean metrics
    print(f"Mean FNR: {mean_fnr}\nMean TNR: {mean_tnr}\nMean FPR: {mean_fpr}\nMean TPR: {mean_tpr}")

# %%
timesteps = 1  # Number of timesteps; adjust based on your data
features_per_timestep = x_train.shape[1]  # Features per timestep

x_train_reshaped = x_train.reshape(-1, timesteps, features_per_timestep)
x_test_reshaped = x_test.reshape(-1, timesteps, features_per_timestep)

# Define the RNN model
output_shape = len(np.unique(y_train))


# Function to create the RNN model with an additional hidden layer
def create_rnn_model(units=32, activation='relu', hidden_units=32, optimizer='adam'):
    model = Sequential([
        SimpleRNN(units, activation=activation, input_shape=(timesteps, features_per_timestep)),
        Dense(units, activation=activation),  # Hidden dense layer
        Dense(output_shape, activation='softmax')  # Output layer
    ])
    model.compile(optimizer=optimizer, loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# Wrapping the model with KerasClassifier
rnn_model = KerasClassifier(model=create_rnn_model, verbose=1, units = [32, 64, 128], batch_size = [32, 64, 128, 256, 512, 1024], epochs = [15, 20, 25])

# Define the parameter grid for hyperparameter tuning
param_dist = {
    'units': [32, 64, 128],
    'batch_size': [32, 64, 128, 256, 512, 1024],
    'epochs': [15, 20, 25]
}

# Setting up RandomizedSearchCV
random_search = RandomizedSearchCV(estimator=rnn_model, param_distributions=param_dist, 
                                   n_iter=10, cv=3, verbose=2)

# Perform hyperparameter tuning using x_val and y_val
random_search_result = random_search.fit(x_train_reshaped, y_train)

# Best parameters
best_params = random_search_result.best_params_
print(f"Best Parameters: {best_params}")

# Train the optimal RNN model with best parameters
optimal_rnn_model = create_rnn_model(units=best_params['units'])
optimal_rnn_model.fit(x_train_reshaped, y_train, batch_size=best_params['batch_size'], epochs=best_params['epochs'])
# Out:
# Fitting 3 folds for each of 10 candidates, totalling 30 fits
# Epoch 1/15
# 1207/1207 [==============================] - 27s 17ms/step - loss: 5.6587 - accuracy: 0.8136
# Epoch 2/15
# 1207/1207 [==============================] - 19s 15ms/step - loss: 1.4670 - accuracy: 0.8739
# Epoch 3/15
# 1207/1207 [==============================] - 20s 16ms/step - loss: 1.1102 - accuracy: 0.8956
# Epoch 4/15
# 1207/1207 [==============================] - 18s 15ms/step - loss: 0.8473 - accuracy: 0.9033
# Epoch 5/15
# 1207/1207 [==============================] - 17s 14ms/step - loss: 0.6494 - accuracy: 0.9089
# Epoch 6/15
# 1207/1207 [==============================] - 18s 15ms/step - loss: 0.4834 - accuracy: 0.9144
# Epoch 7/15
# 1207/1207 [==============================] - 17s 14ms/step - loss: 0.4191 - accuracy: 0.9200
# Epoch 8/15
# 1207/1207 [==============================] - 17s 14ms/step - loss: 0.3512 - accuracy: 0.9246
# Epoch 9/15
# 1207/1207 [==============================] - 16s 14ms/step - loss: 0.3093 - accuracy: 0.9242
# Epoch 10/15
# 1207/1207 [==============================] - 16s 14ms/step - loss: 0.2441 - accuracy: 0.9288
# Epoch 11/15
# 1207/1207 [==============================] - 16s 13ms/step - loss: 0.2370 - accuracy: 0.9291
# Epoch 12/15
# 1207/1207 [==============================] - 16s 13ms/step - loss: 0.2025 - accuracy: 0.9311
# Epoch 13/15
# 1207/1207 [==============================] - 15s 13ms/step - loss: 0.1990 - accuracy: 0.9317
# Epoch 14/15
# 1207/1207 [==============================] - 16s 13ms/step - loss: 0.1937 - accuracy: 0.9315
# Epoch 15/15
# 1207/1207 [==============================] - 16s 13ms/step - loss: 0.1915 - accuracy: 0.9323
# 604/604 [==============================] - 7s 10ms/step
# [CV] END ................batch_size=128, epochs=15, units=64; total time= 4.6min
# Epoch 1/15
# 1207/1207 [==============================] - 20s 13ms/step - loss: 5.7932 - accuracy: 0.8023
# Epoch 2/15
# 1207/1207 [==============================] - 15s 13ms/step - loss: 1.3164 - accuracy: 0.8792
# Epoch 3/15
# 1207/1207 [==============================] - 14s 12ms/step - loss: 0.9803 - accuracy: 0.8937
# Epoch 4/15
# 1207/1207 [==============================] - 13s 11ms/step - loss: 0.8065 - accuracy: 0.9011
# Epoch 5/15
# 1207/1207 [==============================] - 14s 12ms/step - loss: 0.6149 - accuracy: 0.9084
# Epoch 6/15
# 1207/1207 [==============================] - 13s 11ms/step - loss: 0.5139 - accuracy: 0.9159
# Epoch 7/15
# 1207/1207 [==============================] - 14s 12ms/step - loss: 0.4474 - accuracy: 0.9214
# Epoch 8/15
# 1207/1207 [==============================] - 14s 11ms/step - loss: 0.3378 - accuracy: 0.9247
# Epoch 9/15
# 1207/1207 [==============================] - 13s 11ms/step - loss: 0.3436 - accuracy: 0.9255
# Epoch 10/15
# 1207/1207 [==============================] - 14s 12ms/step - loss: 0.2585 - accuracy: 0.9287
# Epoch 11/15
# 1207/1207 [==============================] - 13s 10ms/step - loss: 0.2263 - accuracy: 0.9310
# Epoch 12/15
# 1207/1207 [==============================] - 485s 402ms/step - loss: 0.2226 - accuracy: 0.9306
# Epoch 13/15
# 1207/1207 [==============================] - 11s 10ms/step - loss: 0.2048 - accuracy: 0.9319
# Epoch 14/15
# 1207/1207 [==============================] - 11s 9ms/step - loss: 0.2004 - accuracy: 0.9323
# Epoch 15/15
# 1207/1207 [==============================] - 10s 8ms/step - loss: 0.1929 - accuracy: 0.9331
# 604/604 [==============================] - 5s 7ms/step
# [CV] END ................batch_size=128, epochs=15, units=64; total time=11.4min
# Epoch 1/15
# 1207/1207 [==============================] - 13s 8ms/step - loss: 5.0620 - accuracy: 0.8187
# Epoch 2/15
# 1207/1207 [==============================] - 10s 8ms/step - loss: 0.9989 - accuracy: 0.8841
# Epoch 3/15
# 1207/1207 [==============================] - 10s 8ms/step - loss: 0.6502 - accuracy: 0.8992
# Epoch 4/15
# 1207/1207 [==============================] - 9s 8ms/step - loss: 0.6335 - accuracy: 0.9051
# Epoch 5/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.5728 - accuracy: 0.9100
# Epoch 6/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.4926 - accuracy: 0.9143
# Epoch 7/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.3443 - accuracy: 0.9198
# Epoch 8/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2991 - accuracy: 0.9225
# Epoch 9/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2715 - accuracy: 0.9238
# Epoch 10/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2403 - accuracy: 0.9260
# Epoch 11/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2295 - accuracy: 0.9273
# Epoch 12/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2157 - accuracy: 0.9285
# Epoch 13/15
# 1207/1207 [==============================] - 9s 7ms/step - loss: 0.2153 - accuracy: 0.9275
# Epoch 14/15
# 1207/1207 [==============================] - 9s 8ms/step - loss: 0.2047 - accuracy: 0.9300
# Epoch 15/15
# 1207/1207 [==============================] - 8s 7ms/step - loss: 0.2089 - accuracy: 0.9284
# 604/604 [==============================] - 4s 5ms/step
# [CV] END ................batch_size=128, epochs=15, units=64; total time= 2.3min
# Epoch 1/25
# 4826/4826 [==============================] - 33s 6ms/step - loss: 4.9940 - accuracy: 0.8542
# Epoch 2/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.4668 - accuracy: 0.9033
# Epoch 3/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.3172 - accuracy: 0.9009
# Epoch 4/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2696 - accuracy: 0.9063
# Epoch 5/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2598 - accuracy: 0.9090
# Epoch 6/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2468 - accuracy: 0.9143
# Epoch 7/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2355 - accuracy: 0.9198
# Epoch 8/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2191 - accuracy: 0.9265
# Epoch 9/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2120 - accuracy: 0.9284
# Epoch 10/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2228 - accuracy: 0.9259
# Epoch 11/25
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2072 - accuracy: 0.9295
# Epoch 12/25
# 4826/4826 [==============================] - 30s 6ms/step - loss: 0.1964 - accuracy: 0.9313
# Epoch 13/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.1952 - accuracy: 0.9320
# Epoch 14/25
# 4826/4826 [==============================] - 29s 6ms/step - loss: 0.1956 - accuracy: 0.9323
# Epoch 15/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.1938 - accuracy: 0.9335
# Epoch 16/25
# 4826/4826 [==============================] - 29s 6ms/step - loss: 0.1906 - accuracy: 0.9342
# Epoch 17/25
# 4826/4826 [==============================] - 28s 6ms/step - loss: 0.1902 - accuracy: 0.9338
# Epoch 18/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.1894 - accuracy: 0.9335
# Epoch 19/25
# 4826/4826 [==============================] - 28s 6ms/step - loss: 0.1879 - accuracy: 0.9340
# Epoch 20/25
# 4826/4826 [==============================] - 28s 6ms/step - loss: 0.1857 - accuracy: 0.9351
# Epoch 21/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.1848 - accuracy: 0.9349
# Epoch 22/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.1847 - accuracy: 0.9349
# Epoch 23/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.1858 - accuracy: 0.9358
# Epoch 24/25
# 4826/4826 [==============================] - 28s 6ms/step - loss: 0.1864 - accuracy: 0.9351
# Epoch 25/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.1851 - accuracy: 0.9352
# 2024-01-30 00:57:21.538846: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential_3/simple_rnn_3/while/body/_1/sequential_3/simple_rnn_3/while/simple_rnn_cell/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-01-30 00:57:21.545581: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_3/simple_rnn_3/while/body/_1/sequential_3/simple_rnn_3/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 00:57:21.626143: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] remapper failed: NOT_FOUND: Op type not registered '' in binary running on jupyter-z4shang-40ucsd-2eedu. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.
# 2024-01-30 00:57:21.628269: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_3/simple_rnn_3/while/body/_1/sequential_3/simple_rnn_3/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 00:57:21.628557: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_3/simple_rnn_3/while/body/_1/sequential_3/simple_rnn_3/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 00:57:21.629046: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:615] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential_3/simple_rnn_3/while/body/_1/sequential_3/simple_rnn_3/while/simple_rnn_cell/Relu' does not specify an operation
# 2413/2413 [==============================] - 9s 4ms/step
# [CV] END ................batch_size=32, epochs=25, units=128; total time=11.3min
# Epoch 1/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 2.8951 - accuracy: 0.8588
# Epoch 2/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.3802 - accuracy: 0.9003
# Epoch 3/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.2811 - accuracy: 0.9004
# Epoch 4/25
# 4826/4826 [==============================] - 29s 6ms/step - loss: 0.2554 - accuracy: 0.9077
# Epoch 5/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.2595 - accuracy: 0.9030
# Epoch 6/25
# 4826/4826 [==============================] - 26s 5ms/step - loss: 0.2406 - accuracy: 0.9132
# Epoch 7/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2367 - accuracy: 0.9155
# Epoch 8/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2429 - accuracy: 0.9181
# Epoch 9/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2276 - accuracy: 0.9166
# Epoch 10/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2202 - accuracy: 0.9209
# Epoch 11/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2193 - accuracy: 0.9218
# Epoch 12/25
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2327 - accuracy: 0.9148
# Epoch 13/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2175 - accuracy: 0.9216
# Epoch 14/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2173 - accuracy: 0.9216
# Epoch 15/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2079 - accuracy: 0.9259
# Epoch 16/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2084 - accuracy: 0.9249
# Epoch 17/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2096 - accuracy: 0.9268
# Epoch 18/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2050 - accuracy: 0.9284
# Epoch 19/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2066 - accuracy: 0.9282
# Epoch 20/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2006 - accuracy: 0.9287
# Epoch 21/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2031 - accuracy: 0.9290
# Epoch 22/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2087 - accuracy: 0.9291
# Epoch 23/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2009 - accuracy: 0.9296
# Epoch 24/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2038 - accuracy: 0.9286
# Epoch 25/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1998 - accuracy: 0.9306
# 2413/2413 [==============================] - 8s 3ms/step
# [CV] END ................batch_size=32, epochs=25, units=128; total time=10.2min
# Epoch 1/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 4.0042 - accuracy: 0.8580
# Epoch 2/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.4898 - accuracy: 0.9045
# Epoch 3/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2655 - accuracy: 0.9123
# Epoch 4/25
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2281 - accuracy: 0.9213
# Epoch 5/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2246 - accuracy: 0.9228
# Epoch 6/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2122 - accuracy: 0.9271
# Epoch 7/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2078 - accuracy: 0.9272
# Epoch 8/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2035 - accuracy: 0.9285
# Epoch 9/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1965 - accuracy: 0.9300
# Epoch 10/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2002 - accuracy: 0.9306
# Epoch 11/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1969 - accuracy: 0.9302
# Epoch 12/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1959 - accuracy: 0.9311
# Epoch 13/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1958 - accuracy: 0.9307
# Epoch 14/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1949 - accuracy: 0.9309
# Epoch 15/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1937 - accuracy: 0.9330
# Epoch 16/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1902 - accuracy: 0.9336
# Epoch 17/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1893 - accuracy: 0.9340
# Epoch 18/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1908 - accuracy: 0.9339
# Epoch 19/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1857 - accuracy: 0.9345
# Epoch 20/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1869 - accuracy: 0.9344
# Epoch 21/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1856 - accuracy: 0.9348
# Epoch 22/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1858 - accuracy: 0.9346
# Epoch 23/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.1947 - accuracy: 0.9337
# Epoch 24/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1895 - accuracy: 0.9346
# Epoch 25/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.1847 - accuracy: 0.9347
# 2413/2413 [==============================] - 8s 3ms/step
# [CV] END ................batch_size=32, epochs=25, units=128; total time= 9.9min
# Epoch 1/15
# 4826/4826 [==============================] - 25s 5ms/step - loss: 3.9302 - accuracy: 0.8483
# Epoch 2/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.8163 - accuracy: 0.9002
# Epoch 3/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.3802 - accuracy: 0.9164
# Epoch 4/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2366 - accuracy: 0.9254
# Epoch 5/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2150 - accuracy: 0.9280
# Epoch 6/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2120 - accuracy: 0.9270
# Epoch 7/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2055 - accuracy: 0.9290
# Epoch 8/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.1918 - accuracy: 0.9314
# Epoch 9/15
# 4826/4826 [==============================] - 22s 4ms/step - loss: 0.1946 - accuracy: 0.9309
# Epoch 10/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.1961 - accuracy: 0.9310
# Epoch 11/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.1888 - accuracy: 0.9328
# Epoch 12/15
# 4826/4826 [==============================] - 19s 4ms/step - loss: 0.1857 - accuracy: 0.9335
# Epoch 13/15
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1881 - accuracy: 0.9329
# Epoch 14/15
# 4826/4826 [==============================] - 22s 4ms/step - loss: 0.1888 - accuracy: 0.9331
# Epoch 15/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.1859 - accuracy: 0.9332
#   32/2413 [..............................] - ETA: 7s
# 2024-01-30 01:22:55.722360: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential_6/simple_rnn_6/while/body/_1/sequential_6/simple_rnn_6/while/simple_rnn_cell/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-01-30 01:22:55.729040: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_6/simple_rnn_6/while/body/_1/sequential_6/simple_rnn_6/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:22:55.734336: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] remapper failed: NOT_FOUND: Op type not registered '' in binary running on jupyter-z4shang-40ucsd-2eedu. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.
# 2024-01-30 01:22:55.736297: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_6/simple_rnn_6/while/body/_1/sequential_6/simple_rnn_6/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:22:55.736579: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_6/simple_rnn_6/while/body/_1/sequential_6/simple_rnn_6/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:22:55.737020: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:615] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential_6/simple_rnn_6/while/body/_1/sequential_6/simple_rnn_6/while/simple_rnn_cell/Relu' does not specify an operation
# 2413/2413 [==============================] - 7s 3ms/step
# [CV] END .................batch_size=32, epochs=15, units=64; total time= 5.5min
# Epoch 1/15
# 4826/4826 [==============================] - 24s 4ms/step - loss: 4.3524 - accuracy: 0.8375
# Epoch 2/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.7979 - accuracy: 0.8954
# Epoch 3/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.4113 - accuracy: 0.8961
# Epoch 4/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2934 - accuracy: 0.9003
# Epoch 5/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2478 - accuracy: 0.9082
# Epoch 6/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2330 - accuracy: 0.9160
# Epoch 7/15
# 4826/4826 [==============================] - 22s 4ms/step - loss: 0.2388 - accuracy: 0.9133
# Epoch 8/15
# 4826/4826 [==============================] - 22s 4ms/step - loss: 0.2346 - accuracy: 0.9128
# Epoch 9/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2394 - accuracy: 0.9101
# Epoch 10/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2251 - accuracy: 0.9162
# Epoch 11/15
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2189 - accuracy: 0.9199
# Epoch 12/15
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2146 - accuracy: 0.9210
# Epoch 13/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2159 - accuracy: 0.9206
# Epoch 14/15
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2144 - accuracy: 0.9208
# Epoch 15/15
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2088 - accuracy: 0.9245
# 2413/2413 [==============================] - 9s 3ms/step
# [CV] END .................batch_size=32, epochs=15, units=64; total time= 5.8min
# Epoch 1/15
# 4826/4826 [==============================] - 30s 6ms/step - loss: 4.6636 - accuracy: 0.8392
# Epoch 2/15
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.9977 - accuracy: 0.8981
# Epoch 3/15
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.4358 - accuracy: 0.8956
# Epoch 4/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.3020 - accuracy: 0.9042
# Epoch 5/15
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2429 - accuracy: 0.9095
# Epoch 6/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2346 - accuracy: 0.9147
# Epoch 7/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2286 - accuracy: 0.9173
# Epoch 8/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2308 - accuracy: 0.9168
# Epoch 9/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2242 - accuracy: 0.9200
# Epoch 10/15
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2216 - accuracy: 0.9207
# Epoch 11/15
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2187 - accuracy: 0.9206
# Epoch 12/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2160 - accuracy: 0.9217
# Epoch 13/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2070 - accuracy: 0.9258
# Epoch 14/15
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2118 - accuracy: 0.9234
# Epoch 15/15
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2144 - accuracy: 0.9230
# 2413/2413 [==============================] - 9s 4ms/step
# [CV] END .................batch_size=32, epochs=15, units=64; total time= 6.1min
# Epoch 1/15
# 302/302 [==============================] - 5s 7ms/step - loss: 10.1728 - accuracy: 0.7582
# Epoch 2/15
# 302/302 [==============================] - 2s 7ms/step - loss: 1.1245 - accuracy: 0.8090
# Epoch 3/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.7666 - accuracy: 0.8440
# Epoch 4/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5632 - accuracy: 0.8736
# Epoch 5/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5693 - accuracy: 0.8784
# Epoch 6/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5810 - accuracy: 0.8802
# Epoch 7/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.4092 - accuracy: 0.8971
# Epoch 8/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3758 - accuracy: 0.9037
# Epoch 9/15
# 302/302 [==============================] - 2s 6ms/step - loss: 0.4284 - accuracy: 0.9017
# Epoch 10/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5468 - accuracy: 0.8983
# Epoch 11/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3447 - accuracy: 0.9098
# Epoch 12/15
# 302/302 [==============================] - 2s 8ms/step - loss: 0.3675 - accuracy: 0.9120
# Epoch 13/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.4154 - accuracy: 0.9139
# Epoch 14/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3715 - accuracy: 0.9140
# Epoch 15/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3534 - accuracy: 0.9207
# 151/151 [==============================] - 1s 5ms/step
# [CV] END ................batch_size=512, epochs=15, units=32; total time=  36.5s
# Epoch 1/15
# 302/302 [==============================] - 5s 7ms/step - loss: 11.4822 - accuracy: 0.7002
# Epoch 2/15
# 302/302 [==============================] - 2s 7ms/step - loss: 1.1081 - accuracy: 0.8024
# Epoch 3/15
# 302/302 [==============================] - 2s 7ms/step - loss: 1.0013 - accuracy: 0.8320
# Epoch 4/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.7866 - accuracy: 0.8648
# Epoch 5/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.7087 - accuracy: 0.8737
# Epoch 6/15
# 302/302 [==============================] - 2s 8ms/step - loss: 0.6248 - accuracy: 0.8833
# Epoch 7/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.6876 - accuracy: 0.8836
# Epoch 8/15
# 302/302 [==============================] - 2s 6ms/step - loss: 0.7097 - accuracy: 0.8883
# Epoch 9/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.6432 - accuracy: 0.8932
# Epoch 10/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5725 - accuracy: 0.8956
# Epoch 11/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5521 - accuracy: 0.8977
# Epoch 12/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.4451 - accuracy: 0.9022
# Epoch 13/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5009 - accuracy: 0.9048
# Epoch 14/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.7192 - accuracy: 0.8987
# Epoch 15/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5135 - accuracy: 0.9054
# 151/151 [==============================] - 1s 5ms/step
# [CV] END ................batch_size=512, epochs=15, units=32; total time=  38.4s
# Epoch 1/15
# 302/302 [==============================] - 5s 7ms/step - loss: 12.7388 - accuracy: 0.7354
# Epoch 2/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.8144 - accuracy: 0.8022
# Epoch 3/15
# 302/302 [==============================] - 2s 8ms/step - loss: 0.6735 - accuracy: 0.8552
# Epoch 4/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.7086 - accuracy: 0.8610
# Epoch 5/15
# 302/302 [==============================] - 2s 6ms/step - loss: 0.5105 - accuracy: 0.8774
# Epoch 6/15
# 302/302 [==============================] - 2s 6ms/step - loss: 0.5465 - accuracy: 0.8841
# Epoch 7/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5294 - accuracy: 0.8932
# Epoch 8/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5963 - accuracy: 0.8920
# Epoch 9/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.4871 - accuracy: 0.9011
# Epoch 10/15
# 302/302 [==============================] - 2s 8ms/step - loss: 0.4373 - accuracy: 0.9054
# Epoch 11/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.5224 - accuracy: 0.9021
# Epoch 12/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.4704 - accuracy: 0.9113
# Epoch 13/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3785 - accuracy: 0.9101
# Epoch 14/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3816 - accuracy: 0.9135
# Epoch 15/15
# 302/302 [==============================] - 2s 7ms/step - loss: 0.3271 - accuracy: 0.9172
# 151/151 [==============================] - 1s 5ms/step
# [CV] END ................batch_size=512, epochs=15, units=32; total time=  36.6s
# Epoch 1/15
# 604/604 [==============================] - 6s 6ms/step - loss: 16.0157 - accuracy: 0.7722
# Epoch 2/15
# 604/604 [==============================] - 4s 6ms/step - loss: 1.1825 - accuracy: 0.8670
# Epoch 3/15
# 604/604 [==============================] - 4s 6ms/step - loss: 0.9627 - accuracy: 0.8829
# Epoch 4/15
# 604/604 [==============================] - 4s 6ms/step - loss: 1.0817 - accuracy: 0.8868
# Epoch 5/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.7630 - accuracy: 0.8971
# Epoch 6/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.6628 - accuracy: 0.9014
# Epoch 7/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.9970 - accuracy: 0.9001
# Epoch 8/15
# 604/604 [==============================] - 4s 6ms/step - loss: 0.5949 - accuracy: 0.9070
# Epoch 9/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5472 - accuracy: 0.9107
# Epoch 10/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5621 - accuracy: 0.9142
# Epoch 11/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5868 - accuracy: 0.9155
# Epoch 12/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5065 - accuracy: 0.9190
# Epoch 13/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.3976 - accuracy: 0.9230
# Epoch 14/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.4665 - accuracy: 0.9205
# Epoch 15/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.4505 - accuracy: 0.9224
# 302/302 [==============================] - 2s 4ms/step
# [CV] END ................batch_size=256, epochs=15, units=64; total time=  56.3s
# Epoch 1/15
# 604/604 [==============================] - 5s 6ms/step - loss: 3.6669 - accuracy: 0.7887
# Epoch 2/15
# 604/604 [==============================] - 4s 7ms/step - loss: 1.3900 - accuracy: 0.8619
# Epoch 3/15
# 604/604 [==============================] - 4s 6ms/step - loss: 1.1220 - accuracy: 0.8825
# Epoch 4/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.7714 - accuracy: 0.8970
# Epoch 5/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.7480 - accuracy: 0.9012
# Epoch 6/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5907 - accuracy: 0.9076
# Epoch 7/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.7379 - accuracy: 0.9064
# Epoch 8/15
# 604/604 [==============================] - 3s 5ms/step - loss: 0.5611 - accuracy: 0.9110
# Epoch 9/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.5326 - accuracy: 0.9142
# Epoch 10/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4956 - accuracy: 0.9183
# Epoch 11/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4489 - accuracy: 0.9212
# Epoch 12/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4538 - accuracy: 0.9226
# Epoch 13/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.3632 - accuracy: 0.9247
# Epoch 14/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.3308 - accuracy: 0.9269
# Epoch 15/15
# 604/604 [==============================] - 3s 6ms/step - loss: 0.3644 - accuracy: 0.9267
# 302/302 [==============================] - 2s 5ms/step
# [CV] END ................batch_size=256, epochs=15, units=64; total time= 1.0min
# Epoch 1/15
# 604/604 [==============================] - 8s 8ms/step - loss: 11.8990 - accuracy: 0.7637
# Epoch 2/15
# 604/604 [==============================] - 4s 7ms/step - loss: 1.0686 - accuracy: 0.8604
# Epoch 3/15
# 604/604 [==============================] - 4s 6ms/step - loss: 0.9937 - accuracy: 0.8826
# Epoch 4/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.6417 - accuracy: 0.8998
# Epoch 5/15
# 604/604 [==============================] - 5s 8ms/step - loss: 0.6506 - accuracy: 0.9024
# Epoch 6/15
# 604/604 [==============================] - 5s 8ms/step - loss: 0.6082 - accuracy: 0.9061
# Epoch 7/15
# 604/604 [==============================] - 4s 6ms/step - loss: 0.6762 - accuracy: 0.9046
# Epoch 8/15
# 604/604 [==============================] - 5s 8ms/step - loss: 0.6320 - accuracy: 0.9096
# Epoch 9/15
# 604/604 [==============================] - 5s 7ms/step - loss: 0.5453 - accuracy: 0.9136
# Epoch 10/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4618 - accuracy: 0.9203
# Epoch 11/15
# 604/604 [==============================] - 5s 8ms/step - loss: 0.4576 - accuracy: 0.9219
# Epoch 12/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4648 - accuracy: 0.9241
# Epoch 13/15
# 604/604 [==============================] - 4s 6ms/step - loss: 0.3805 - accuracy: 0.9271
# Epoch 14/15
# 604/604 [==============================] - 4s 7ms/step - loss: 0.4414 - accuracy: 0.9238
# Epoch 15/15
# 604/604 [==============================] - 5s 8ms/step - loss: 0.3375 - accuracy: 0.9280
# 302/302 [==============================] - 3s 8ms/step
# [CV] END ................batch_size=256, epochs=15, units=64; total time= 1.2min
# Epoch 1/15
# 302/302 [==============================] - 6s 11ms/step - loss: 7.7783 - accuracy: 0.7411
# Epoch 2/15
# 302/302 [==============================] - 3s 11ms/step - loss: 2.2405 - accuracy: 0.8231
# Epoch 3/15
# 302/302 [==============================] - 4s 13ms/step - loss: 2.2774 - accuracy: 0.8471
# Epoch 4/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.2892 - accuracy: 0.8771
# Epoch 5/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.3111 - accuracy: 0.8848
# Epoch 6/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.2337 - accuracy: 0.8920
# Epoch 7/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.6346 - accuracy: 0.9040
# Epoch 8/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.2301 - accuracy: 0.8938
# Epoch 9/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.8256 - accuracy: 0.9019
# Epoch 10/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.6477 - accuracy: 0.9095
# Epoch 11/15
# 302/302 [==============================] - 3s 10ms/step - loss: 0.5683 - accuracy: 0.9109
# Epoch 12/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.5615 - accuracy: 0.9132
# Epoch 13/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.5501 - accuracy: 0.9170
# Epoch 14/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.4193 - accuracy: 0.9213
# Epoch 15/15
# 302/302 [==============================] - 3s 10ms/step - loss: 0.4661 - accuracy: 0.9227
# 151/151 [==============================] - 1s 7ms/step
# [CV] END ...............batch_size=512, epochs=15, units=128; total time=  55.0s
# Epoch 1/15
# 302/302 [==============================] - 6s 11ms/step - loss: 8.1208 - accuracy: 0.7687
# Epoch 2/15
# 302/302 [==============================] - 3s 11ms/step - loss: 2.7456 - accuracy: 0.8332
# Epoch 3/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.3441 - accuracy: 0.8705
# Epoch 4/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.3461 - accuracy: 0.8834
# Epoch 5/15
# 302/302 [==============================] - 4s 12ms/step - loss: 1.4451 - accuracy: 0.8881
# Epoch 6/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.9165 - accuracy: 0.9003
# Epoch 7/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.9576 - accuracy: 0.8991
# Epoch 8/15
# 302/302 [==============================] - 3s 10ms/step - loss: 1.0304 - accuracy: 0.9009
# Epoch 9/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.7704 - accuracy: 0.9064
# Epoch 10/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.5034 - accuracy: 0.9138
# Epoch 11/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.6048 - accuracy: 0.9145
# Epoch 12/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.8652 - accuracy: 0.9133
# Epoch 13/15
# 302/302 [==============================] - 4s 13ms/step - loss: 0.4974 - accuracy: 0.9202
# Epoch 14/15
# 302/302 [==============================] - 3s 12ms/step - loss: 0.5627 - accuracy: 0.9213
# Epoch 15/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.5415 - accuracy: 0.9224
# 151/151 [==============================] - 2s 7ms/step
# [CV] END ...............batch_size=512, epochs=15, units=128; total time=  56.7s
# Epoch 1/15
# 302/302 [==============================] - 6s 13ms/step - loss: 17.1908 - accuracy: 0.7406
# Epoch 2/15
# 302/302 [==============================] - 3s 12ms/step - loss: 2.7689 - accuracy: 0.8171
# Epoch 3/15
# 302/302 [==============================] - 4s 13ms/step - loss: 2.6512 - accuracy: 0.8397
# Epoch 4/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.9393 - accuracy: 0.8550
# Epoch 5/15
# 302/302 [==============================] - 3s 11ms/step - loss: 2.2210 - accuracy: 0.8531
# Epoch 6/15
# 302/302 [==============================] - 4s 13ms/step - loss: 1.5360 - accuracy: 0.8728
# Epoch 7/15
# 302/302 [==============================] - 3s 11ms/step - loss: 1.3841 - accuracy: 0.8818
# Epoch 8/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.8940 - accuracy: 0.8972
# Epoch 9/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.9431 - accuracy: 0.9009
# Epoch 10/15
# 302/302 [==============================] - 3s 12ms/step - loss: 1.1678 - accuracy: 0.8986
# Epoch 11/15
# 302/302 [==============================] - 4s 12ms/step - loss: 1.5597 - accuracy: 0.8984
# Epoch 12/15
# 302/302 [==============================] - 3s 10ms/step - loss: 0.6889 - accuracy: 0.9130
# Epoch 13/15
# 302/302 [==============================] - 3s 11ms/step - loss: 0.7573 - accuracy: 0.9136
# Epoch 14/15
# 302/302 [==============================] - 3s 10ms/step - loss: 0.5873 - accuracy: 0.9156
# Epoch 15/15
# 302/302 [==============================] - 4s 12ms/step - loss: 0.5519 - accuracy: 0.9191
# 151/151 [==============================] - 2s 9ms/step
# [CV] END ...............batch_size=512, epochs=15, units=128; total time=  56.6s
# Epoch 1/25
# 4826/4826 [==============================] - 28s 5ms/step - loss: 3.0233 - accuracy: 0.8407
# Epoch 2/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.6276 - accuracy: 0.8946
# Epoch 3/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.3089 - accuracy: 0.9046
# Epoch 4/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2627 - accuracy: 0.9097
# Epoch 5/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2650 - accuracy: 0.9121
# Epoch 6/25
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2504 - accuracy: 0.9129
# Epoch 7/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2341 - accuracy: 0.9191
# Epoch 8/25
# 4826/4826 [==============================] - 22s 5ms/step - loss: 0.2284 - accuracy: 0.9229
# Epoch 9/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2102 - accuracy: 0.9256
# Epoch 10/25
# 4826/4826 [==============================] - 21s 4ms/step - loss: 0.2120 - accuracy: 0.9249
# Epoch 11/25
# 4826/4826 [==============================] - 19s 4ms/step - loss: 0.2119 - accuracy: 0.9251
# Epoch 12/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2040 - accuracy: 0.9274
# Epoch 13/25
# 4826/4826 [==============================] - 24s 5ms/step - loss: 0.2091 - accuracy: 0.9245
# Epoch 14/25
# 4826/4826 [==============================] - 23s 5ms/step - loss: 0.2055 - accuracy: 0.9275
# Epoch 15/25
# 4826/4826 [==============================] - 20s 4ms/step - loss: 0.2079 - accuracy: 0.9252
# Epoch 16/25
# 4826/4826 [==============================] - 18s 4ms/step - loss: 0.1948 - accuracy: 0.9299
# Epoch 17/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1988 - accuracy: 0.9299
# Epoch 18/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1925 - accuracy: 0.9315
# Epoch 19/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1943 - accuracy: 0.9308
# Epoch 20/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1933 - accuracy: 0.9324
# Epoch 21/25
# 4826/4826 [==============================] - 17s 4ms/step - loss: 0.1890 - accuracy: 0.9331
# Epoch 22/25
# 4826/4826 [==============================] - 18s 4ms/step - loss: 0.1887 - accuracy: 0.9329
# Epoch 23/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1943 - accuracy: 0.9335
# Epoch 24/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1900 - accuracy: 0.9329
# Epoch 25/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1906 - accuracy: 0.9338
#   39/2413 [..............................] - ETA: 6s
# 2024-01-30 01:51:23.732674: W tensorflow/core/grappler/utils/graph_view.cc:849] No registered '' OpKernel for CPU devices compatible with node {{node sequential_18/simple_rnn_18/while/body/_1/sequential_18/simple_rnn_18/while/simple_rnn_cell/Relu}}
# 	.  Registered:  <no registered kernels>
#
# 2024-01-30 01:51:23.738762: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-toposort,tfg-shape-inference{graph-version=0},tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_18/simple_rnn_18/while/body/_1/sequential_18/simple_rnn_18/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:51:23.743839: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] remapper failed: NOT_FOUND: Op type not registered '' in binary running on jupyter-z4shang-40ucsd-2eedu. Make sure the Op and Kernel are registered in the binary running in this process. Note that if you are loading a saved graph which used ops from tf.contrib (e.g. `tf.contrib.resampler`), accessing should be done before importing the graph, as contrib ops are lazily registered when the module is first accessed.
# 2024-01-30 01:51:23.745742: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_18/simple_rnn_18/while/body/_1/sequential_18/simple_rnn_18/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:51:23.746016: E tensorflow/core/grappler/optimizers/tfg_optimizer_hook.cc:135] tfg_optimizer{any(tfg-consolidate-attrs,tfg-functional-to-region,tfg.func(tfg-cf-sink),tfg-region-to-functional{force-control-capture=true},tfg-lift-legacy-call,symbol-privatize{},symbol-dce,tfg-prepare-attrs-export)} failed: INVALID_ARGUMENT: Node sequential_18/simple_rnn_18/while/body/_1/sequential_18/simple_rnn_18/while/simple_rnn_cell/Relu has an empty op name
# 	when importing GraphDef to MLIR module in GrapplerHook
# 2024-01-30 01:51:23.746479: W tensorflow/core/common_runtime/optimize_function_graph_utils.cc:615] Ignoring multi-device function optimization failure: INVALID_ARGUMENT: Node 'sequential_18/simple_rnn_18/while/body/_1/sequential_18/simple_rnn_18/while/simple_rnn_cell/Relu' does not specify an operation
# 2413/2413 [==============================] - 6s 2ms/step
# [CV] END .................batch_size=32, epochs=25, units=64; total time= 8.7min
# Epoch 1/25
# 4826/4826 [==============================] - 19s 3ms/step - loss: 3.8606 - accuracy: 0.8319
# Epoch 2/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.8507 - accuracy: 0.8960
# Epoch 3/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.3660 - accuracy: 0.9102
# Epoch 4/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.2604 - accuracy: 0.9128
# Epoch 5/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2341 - accuracy: 0.9221
# Epoch 6/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.2101 - accuracy: 0.9285
# Epoch 7/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.2083 - accuracy: 0.9275
# Epoch 8/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1958 - accuracy: 0.9303
# Epoch 9/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1944 - accuracy: 0.9307
# Epoch 10/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1969 - accuracy: 0.9310
# Epoch 11/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1899 - accuracy: 0.9321
# Epoch 12/25
# 4826/4826 [==============================] - 17s 4ms/step - loss: 0.1888 - accuracy: 0.9328
# Epoch 13/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1841 - accuracy: 0.9330
# Epoch 14/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1906 - accuracy: 0.9329
# Epoch 15/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1873 - accuracy: 0.9331
# Epoch 16/25
# 4826/4826 [==============================] - 20s 4ms/step - loss: 0.1883 - accuracy: 0.9328
# Epoch 17/25
# 4826/4826 [==============================] - 28s 6ms/step - loss: 0.1832 - accuracy: 0.9341
# Epoch 18/25
# 4826/4826 [==============================] - 27s 6ms/step - loss: 0.1845 - accuracy: 0.9333
# Epoch 19/25
# 4826/4826 [==============================] - 17s 4ms/step - loss: 0.1889 - accuracy: 0.9340
# Epoch 20/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1845 - accuracy: 0.9340
# Epoch 21/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.1828 - accuracy: 0.9341
# Epoch 22/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1852 - accuracy: 0.9346
# Epoch 23/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1863 - accuracy: 0.9345
# Epoch 24/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1817 - accuracy: 0.9348
# Epoch 25/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.1821 - accuracy: 0.9351
# 2413/2413 [==============================] - 7s 3ms/step
# [CV] END .................batch_size=32, epochs=25, units=64; total time= 7.5min
# Epoch 1/25
# 4826/4826 [==============================] - 20s 4ms/step - loss: 5.2662 - accuracy: 0.8244
# Epoch 2/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.7582 - accuracy: 0.8910
# Epoch 3/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.3231 - accuracy: 0.9086
# Epoch 4/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2699 - accuracy: 0.9048
# Epoch 5/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2479 - accuracy: 0.9119
# Epoch 6/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2438 - accuracy: 0.9103
# Epoch 7/25
# 4826/4826 [==============================] - 17s 4ms/step - loss: 0.2351 - accuracy: 0.9154
# Epoch 8/25
# 4826/4826 [==============================] - 25s 5ms/step - loss: 0.2220 - accuracy: 0.9188
# Epoch 9/25
# 4826/4826 [==============================] - 22s 4ms/step - loss: 0.2301 - accuracy: 0.9202
# Epoch 10/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2217 - accuracy: 0.9232
# Epoch 11/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2127 - accuracy: 0.9252
# Epoch 12/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2053 - accuracy: 0.9271
# Epoch 13/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2048 - accuracy: 0.9257
# Epoch 14/25
# 4826/4826 [==============================] - 17s 3ms/step - loss: 0.2064 - accuracy: 0.9266
# Epoch 15/25
# 4826/4826 [==============================] - 16s 3ms/step - loss: 0.2069 - accuracy: 0.9284
# Epoch 16/25
# ...
# Epoch 5/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.4668 - accuracy: 0.9108
# Epoch 6/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.3775 - accuracy: 0.9174
# Epoch 7/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.3172 - accuracy: 0.9195
# Epoch 8/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2659 - accuracy: 0.9214
# Epoch 9/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2265 - accuracy: 0.9237
# Epoch 10/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2173 - accuracy: 0.9240
# Epoch 11/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2054 - accuracy: 0.9280
# Epoch 12/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2044 - accuracy: 0.9273
# Epoch 13/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2028 - accuracy: 0.9292
# Epoch 14/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1971 - accuracy: 0.9302
# Epoch 15/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1932 - accuracy: 0.9320
# 1207/1207 [==============================] - 4s 3ms/step
# [CV] END .................batch_size=64, epochs=15, units=32; total time= 2.4min
# Epoch 1/15
# 2413/2413 [==============================] - 12s 4ms/step - loss: 4.2049 - accuracy: 0.7909
# Epoch 2/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 1.7769 - accuracy: 0.8724
# Epoch 3/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 1.1402 - accuracy: 0.8866
# Epoch 4/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.9324 - accuracy: 0.8943
# Epoch 5/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.7278 - accuracy: 0.8997
# Epoch 6/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.4844 - accuracy: 0.9068
# Epoch 7/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.3889 - accuracy: 0.9128
# Epoch 8/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.3171 - accuracy: 0.9175
# Epoch 9/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2755 - accuracy: 0.9245
# Epoch 10/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2348 - accuracy: 0.9277
# Epoch 11/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2248 - accuracy: 0.9285
# Epoch 12/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2092 - accuracy: 0.9299
# Epoch 13/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2086 - accuracy: 0.9299
# Epoch 14/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2039 - accuracy: 0.9304
# Epoch 15/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1994 - accuracy: 0.9307
# 1207/1207 [==============================] - 4s 3ms/step
# [CV] END .................batch_size=64, epochs=15, units=32; total time= 2.4min
# Epoch 1/15
# 2413/2413 [==============================] - 12s 4ms/step - loss: 4.9373 - accuracy: 0.8234
# Epoch 2/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.6704 - accuracy: 0.8924
# Epoch 3/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.5348 - accuracy: 0.9058
# Epoch 4/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.4570 - accuracy: 0.9129
# Epoch 5/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.3339 - accuracy: 0.9184
# Epoch 6/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.3054 - accuracy: 0.9216
# Epoch 7/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2434 - accuracy: 0.9231
# Epoch 8/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2419 - accuracy: 0.9255
# Epoch 9/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2243 - accuracy: 0.9253
# Epoch 10/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2229 - accuracy: 0.9245
# Epoch 11/15
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.2066 - accuracy: 0.9293
# Epoch 12/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1988 - accuracy: 0.9311
# Epoch 13/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2006 - accuracy: 0.9302
# Epoch 14/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1954 - accuracy: 0.9321
# Epoch 15/15
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1902 - accuracy: 0.9332
# 1207/1207 [==============================] - 4s 3ms/step
# [CV] END .................batch_size=64, epochs=15, units=32; total time= 2.5min
# Epoch 1/25
# 2413/2413 [==============================] - 14s 4ms/step - loss: 4.4032 - accuracy: 0.8248
# Epoch 2/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 1.5766 - accuracy: 0.8900
# Epoch 3/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 1.0597 - accuracy: 0.9016
# Epoch 4/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.6329 - accuracy: 0.9092
# Epoch 5/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.3750 - accuracy: 0.9166
# Epoch 6/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2756 - accuracy: 0.9219
# Epoch 7/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2401 - accuracy: 0.9229
# Epoch 8/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2329 - accuracy: 0.9246
# Epoch 9/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2066 - accuracy: 0.9277
# Epoch 10/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2139 - accuracy: 0.9265
# Epoch 11/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1998 - accuracy: 0.9291
# Epoch 12/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1974 - accuracy: 0.9301
# Epoch 13/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2004 - accuracy: 0.9296
# Epoch 14/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1945 - accuracy: 0.9307
# Epoch 15/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1921 - accuracy: 0.9317
# Epoch 16/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1918 - accuracy: 0.9317
# Epoch 17/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1929 - accuracy: 0.9325
# Epoch 18/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1833 - accuracy: 0.9340
# Epoch 19/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1839 - accuracy: 0.9338
# Epoch 20/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1820 - accuracy: 0.9342
# Epoch 21/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1851 - accuracy: 0.9346
# Epoch 22/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1887 - accuracy: 0.9337
# Epoch 23/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1790 - accuracy: 0.9349
# Epoch 24/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1814 - accuracy: 0.9347
# Epoch 25/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1792 - accuracy: 0.9351
# 1207/1207 [==============================] - 4s 3ms/step
# [CV] END .................batch_size=64, epochs=25, units=64; total time= 4.3min
# Epoch 1/25
# 2413/2413 [==============================] - 12s 4ms/step - loss: 7.9976 - accuracy: 0.8207
# Epoch 2/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 1.5916 - accuracy: 0.8832
# Epoch 3/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.9865 - accuracy: 0.8988
# Epoch 4/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.5608 - accuracy: 0.9058
# Epoch 5/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.3629 - accuracy: 0.9115
# Epoch 6/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2532 - accuracy: 0.9194
# Epoch 7/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2303 - accuracy: 0.9217
# Epoch 8/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2180 - accuracy: 0.9242
# Epoch 9/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2122 - accuracy: 0.9242
# Epoch 10/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2022 - accuracy: 0.9280
# Epoch 11/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1991 - accuracy: 0.9296
# Epoch 12/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1978 - accuracy: 0.9304
# Epoch 13/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1946 - accuracy: 0.9303
# Epoch 14/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1933 - accuracy: 0.9311
# Epoch 15/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1969 - accuracy: 0.9307
# Epoch 16/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1912 - accuracy: 0.9324
# Epoch 17/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1884 - accuracy: 0.9325
# Epoch 18/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1859 - accuracy: 0.9328
# Epoch 19/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1846 - accuracy: 0.9337
# Epoch 20/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1849 - accuracy: 0.9332
# Epoch 21/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1845 - accuracy: 0.9333
# Epoch 22/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1843 - accuracy: 0.9332
# Epoch 23/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1845 - accuracy: 0.9333
# Epoch 24/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1827 - accuracy: 0.9339
# Epoch 25/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1823 - accuracy: 0.9337
# 1207/1207 [==============================] - 3s 2ms/step
# [CV] END .................batch_size=64, epochs=25, units=64; total time= 4.2min
# Epoch 1/25
# 2413/2413 [==============================] - 8s 3ms/step - loss: 4.9327 - accuracy: 0.8328
# Epoch 2/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 1.3372 - accuracy: 0.8891
# Epoch 3/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.7199 - accuracy: 0.9052
# Epoch 4/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.4236 - accuracy: 0.9176
# Epoch 5/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.3113 - accuracy: 0.9233
# Epoch 6/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2343 - accuracy: 0.9258
# Epoch 7/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2102 - accuracy: 0.9286
# Epoch 8/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2046 - accuracy: 0.9283
# Epoch 9/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2060 - accuracy: 0.9290
# Epoch 10/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2025 - accuracy: 0.9295
# Epoch 11/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1954 - accuracy: 0.9315
# Epoch 12/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2006 - accuracy: 0.9318
# Epoch 13/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.2075 - accuracy: 0.9270
# Epoch 14/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1941 - accuracy: 0.9310
# Epoch 15/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1902 - accuracy: 0.9322
# Epoch 16/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1997 - accuracy: 0.9303
# Epoch 17/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1860 - accuracy: 0.9333
# Epoch 18/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1949 - accuracy: 0.9303
# Epoch 19/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1897 - accuracy: 0.9298
# Epoch 20/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1895 - accuracy: 0.9292
# Epoch 21/25
# 2413/2413 [==============================] - 9s 4ms/step - loss: 0.1865 - accuracy: 0.9307
# Epoch 22/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1885 - accuracy: 0.9316
# Epoch 23/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1890 - accuracy: 0.9297
# Epoch 24/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1865 - accuracy: 0.9301
# Epoch 25/25
# 2413/2413 [==============================] - 10s 4ms/step - loss: 0.1859 - accuracy: 0.9310
# 1207/1207 [==============================] - 4s 3ms/step
# [CV] END .................batch_size=64, epochs=25, units=64; total time= 4.2min
# Epoch 1/15
# 1810/1810 [==============================] - 10s 5ms/step - loss: 3.5607 - accuracy: 0.8004
# Epoch 2/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 1.4645 - accuracy: 0.8724
# Epoch 3/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.8484 - accuracy: 0.8942
# Epoch 4/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.6360 - accuracy: 0.9035
# Epoch 5/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.4667 - accuracy: 0.9103
# Epoch 6/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.3600 - accuracy: 0.9166
# Epoch 7/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.2914 - accuracy: 0.9219
# Epoch 8/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.2519 - accuracy: 0.9253
# Epoch 9/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.2392 - accuracy: 0.9261
# Epoch 10/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.2185 - accuracy: 0.9286
# Epoch 11/15
# 1810/1810 [==============================] - 7s 4ms/step - loss: 0.2069 - accuracy: 0.9304
# Epoch 12/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.1985 - accuracy: 0.9317
# Epoch 13/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.2010 - accuracy: 0.9310
# Epoch 14/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.1880 - accuracy: 0.9338
# Epoch 15/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.1871 - accuracy: 0.9342
# Best Parameters: {'units': 64, 'epochs': 15, 'batch_size': 128}
# Epoch 1/15
# 1810/1810 [==============================] - 12s 5ms/step - loss: 4.4828 - accuracy: 0.8205
# Epoch 2/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 1.3309 - accuracy: 0.8819
# Epoch 3/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.9103 - accuracy: 0.8957
# Epoch 4/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.7021 - accuracy: 0.9083
# Epoch 5/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.5073 - accuracy: 0.9155
# Epoch 6/15
# 1810/1810 [==============================] - 8s 4ms/step - loss: 0.3791 - accuracy: 0.9214
# Epoch 7/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.2633 - accuracy: 0.9274
# Epoch 8/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.2514 - accuracy: 0.9281
# Epoch 9/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.2178 - accuracy: 0.9289
# Epoch 10/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.1999 - accuracy: 0.9312
# Epoch 11/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.2018 - accuracy: 0.9311
# Epoch 12/15
# 1810/1810 [==============================] - 9s 5ms/step - loss: 0.1944 - accuracy: 0.9313
# Epoch 13/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.1934 - accuracy: 0.9321
# Epoch 14/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.1877 - accuracy: 0.9330
# Epoch 15/15
# 1810/1810 [==============================] - 8s 5ms/step - loss: 0.1894 - accuracy: 0.9326

# %%
calculate_performance_metrics(x_test_reshaped, y_test, optimal_rnn_model)
# Out:
# 3103/3103 [==============================] - 22s 7ms/step
# Precision: 0.901511375773276
# Accuracy: 0.8992647799375566
# F1 Score: 0.7890605587467102
# AUC: 0.977944504047672
# Mean FNR: 0.24386009678008888
# Mean TNR: 0.9724974745994196
# Mean FPR: 0.02750252540058039
# Mean TPR: 0.7561399032199111
